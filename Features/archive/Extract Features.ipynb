# %%
from src.DataProvider import DataProvider
from src.DataFeatures import DataFeatures
import os

# %%
features = DataFeatures()

# %%
dfo = DataProvider("data/Omega")
for loop in dfo:
    trial = dfo.df
    debug = 1
    while debug:
        try:
            behaviour_features = features.extractFeatures(trial)
            debug = 0
        except Exception as inst:
            bugPos = inst.args[0]
            print(bugPos)
            trial = dfo.deleteBugRound(trial,bugPos)
            print("**********")
    behaviour_features.to_pickle(dfp.fileName.replace(".pickle","-F.pickle"))
# Out:
# load omegaL-28-Nov-2020-1.pickle
# round 5 of omegaL-28-Nov-2020-1.pickle has pacman position in wall
# load omegaL-04-Mar-2021-1.pickle
# round 2 of omegaL-04-Mar-2021-1.pickle has pacman position in wall

# %%
dfo = DataProvider("data/Patamon")
for loop in dfo:
    trial = dfo.df
    debug = 1
    while debug:
        try:
            behaviour_features = features.extractFeatures(trial)
            debug = 0
        except Exception as inst:
            bugPos = inst.args[0]
            print(bugPos)
            trial = dfo.deleteBugRound(trial,bugPos)
            print("**********")
    behaviour_features.to_pickle(dfp.fileName.replace(".pickle","-F.pickle"))
# Out:
# load Patamon-17-Jun-2021-1.pickle
# load Patamon-23-Feb-2021-1.pickle
# load Patamon-03-May-2021-1.pickle
# load Patamon-10-Jun-2021-1.pickle
# load Patamon-21-Feb-2021-1.pickle
# load Patamon-25-Apr-2021-1.pickle
# load Patamon-28-Jul-2021-3.pickle
# load Patamon-27-May-2021-1.pickle
# load Patamon-18-Aug-2021-1.pickle
# load Patamon-23-Mar-2021-2.pickle
# load Patamon-24-Mar-2021-1.pickle
# load Patamon-28-Apr-2021-1.pickle
# load Patamon-26-Apr-2021-1.pickle
# load Patamon-17-Aug-2021-1.pickle
# load Patamon-03-Jun-2021-2.pickle
# load Patamon-22-Feb-2021-1.pickle
# load Patamon-10-Mar-2021-1.pickle
# load Patamon-12-Apr-2021-2.pickle
# load Patamon-20-Jul-2021-1.pickle
# load Patamon-20-Aug-2021-1.pickle
# load Patamon-19-Jun-2021-1.pickle
# load Patamon-05-Jun-2021-3.pickle
# load Patamon-13-Feb-2021-2.pickle
# round 16 of Patamon-13-Feb-2021-2.pickle has pacman position in wall
# something wrong with Patamon-13-Feb-2021-2.pickle
# **********
# load Patamon-06-May-2021-1.pickle
# round 3 of Patamon-06-May-2021-1.pickle has pacman position in wall
# load Patamon-10-Aug-2021-1.pickle
# load Patamon-29-Jul-2021-2.pickle
# load Patamon-18-Feb-2021-1.pickle
# load Patamon-25-Jun-2021-1.pickle
# load Patamon-26-Feb-2021-2.pickle
# load Patamon-28-May-2021-1.pickle
# load Patamon-15-Mar-2021-1.pickle
# load Patamon-21-May-2021-1.pickle
# load Patamon-06-Jul-2021-1.pickle
# round 13 of Patamon-06-Jul-2021-1.pickle has pacman position in wall
# load Patamon-31-May-2021-1.pickle
# load Patamon-15-Apr-2021-3.pickle
# load Patamon-20-Feb-2021-1.pickle
# load Patamon-18-May-2021-2.pickle
# load Patamon-12-Mar-2021-1.pickle
# load Patamon-08-Apr-2021-1.pickle
# load Patamon-19-May-2021-1.pickle
# load Patamon-02-Jun-2021-1.pickle
# load Patamon-09-Apr-2021-1.pickle
# load Patamon-17-May-2021-1.pickle
# round 15 of Patamon-17-May-2021-1.pickle has pacman position in wall
# load Patamon-23-Mar-2021-3.pickle
# load Patamon-09-Jun-2021-3.pickle
# load Patamon-16-Aug-2021-1.pickle
# load Patamon-13-Mar-2021-1.pickle
# load Patamon-10-May-2021-1.pickle
# round 15 of Patamon-10-May-2021-1.pickle has pacman position in wall
# load Patamon-15-Apr-2021-4.pickle
# load Patamon-15-Apr-2021-2.pickle
# load Patamon-05-Jun-2021-2.pickle
# load Patamon-09-Jul-2021-1.pickle
# load Patamon-01-Jun-2021-1.pickle
# load Patamon-10-Mar-2021-2.pickle
# round 36 of Patamon-10-Mar-2021-2.pickle has pacman position in wall
# load Patamon-19-May-2021-2.pickle
# load Patamon-11-Mar-2021-1.pickle
# load Patamon-25-May-2021-1.pickle
# load Patamon-30-Jun-2021-1.pickle
# load Patamon-12-Apr-2021-1.pickle
# load Patamon-09-Jun-2021-2.pickle
# load Patamon-26-Mar-2021-1.pickle
# round 34 of Patamon-26-Mar-2021-1.pickle has pacman position in wall
# load Patamon-29-Apr-2021-1.pickle
# load Patamon-28-Apr-2021-2.pickle
# load Patamon-27-Apr-2021-1.pickle
# round 19 of Patamon-27-Apr-2021-1.pickle has pacman position in wall
# load Patamon-01-Jul-2021-2.pickle
# load Patamon-16-Jun-2021-1.pickle
# load Patamon-13-Feb-2021-1.pickle
# round 1 of Patamon-13-Feb-2021-1.pickle has pacman position in wall
# something wrong with Patamon-13-Feb-2021-1.pickle
# **********
# load Patamon-06-Jun-2021-1.pickle
# load Patamon-14-May-2021-1.pickle
# load Patamon-14-Mar-2021-1.pickle
# load Patamon-18-Jun-2021-1.pickle
# round 34 of Patamon-18-Jun-2021-1.pickle has pacman position in wall
# load Patamon-07-Jun-2021-1.pickle
# load Patamon-01-Jul-2021-1.pickle
# load Patamon-14-Feb-2021-2.pickle
# load Patamon-21-Jun-2021-1.pickle
# load Patamon-07-Jul-2021-1.pickle
# load Patamon-20-May-2021-1.pickle
# round 36 of Patamon-20-May-2021-1.pickle has pacman position in wall
# load Patamon-28-Jul-2021-2.pickle
# load Patamon-21-Jul-2021-1.pickle
# load Patamon-24-Feb-2021-2.pickle
# load Patamon-03-Aug-2021-1.pickle
# load Patamon-15-Jun-2021-1.pickle
# load Patamon-13-Aug-2021-1.pickle
# load Patamon-01-May-2021-1.pickle
# load Patamon-25-Mar-2021-1.pickle
# load Patamon-22-Jun-2021-1.pickle
# load Patamon-24-May-2021-1.pickle
# load Patamon-10-Apr-2021-1.pickle
# round 37 of Patamon-10-Apr-2021-1.pickle has pacman position in wall
# load Patamon-05-Jun-2021-1.pickle
# load Patamon-03-Jun-2021-1.pickle
# load Patamon-17-Jun-2021-3.pickle
# load Patamon-15-May-2021-1.pickle
# round 16 of Patamon-15-May-2021-1.pickle has pacman position in wall
# load Patamon-02-Jul-2021-1.pickle
# load Patamon-11-May-2021-1.pickle
# load Patamon-24-Jun-2021-1.pickle
# load Patamon-12-Aug-2021-1.pickle
# load Patamon-25-Apr-2021-2.pickle
# load Patamon-11-Jun-2021-1.pickle
# load Patamon-13-Apr-2021-1.pickle
# load Patamon-26-Feb-2021-1.pickle
# load Patamon-05-Jul-2021-1.pickle
# load Patamon-26-Mar-2021-2.pickle
# load Patamon-31-Jul-2021-1.pickle
# load Patamon-29-Jun-2021-1.pickle
# load Patamon-14-Jun-2021-1.pickle
# load Patamon-06-Aug-2021-1.pickle
# load Patamon-13-Jun-2021-1.pickle
# load Patamon-27-Feb-2021-1.pickle
# round 6 of Patamon-27-Feb-2021-1.pickle has pacman position in wall
# something wrong with Patamon-27-Feb-2021-1.pickle
# **********
